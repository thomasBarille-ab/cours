# %%
#importation du jeu de données

df = pd.read_csv("clean_dataset.csv")
df
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0               2    -122.24     37.85                52.0       1467.0
# 1               3    -122.25     37.85                52.0       1274.0
# 2               4    -122.25     37.85                52.0       1627.0
# 3               5    -122.25     37.85                52.0        919.0
# 4               6    -122.25     37.84                52.0       2535.0
# ...           ...        ...       ...                 ...          ...
# 15813       20635    -121.09     39.48                25.0       1665.0
# 15814       20636    -121.21     39.49                18.0        697.0
# 15815       20637    -121.22     39.43                17.0       2254.0
# 15816       20638    -121.32     39.43                18.0       1860.0
# 15817       20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               190.0       496.0       177.0         7.2574
# 1               235.0       558.0       219.0         5.6431
# 2               280.0       565.0       259.0         3.8462
# 3               213.0       413.0       193.0         4.0368
# 4               489.0      1094.0       514.0         3.6591
# ...               ...         ...         ...            ...
# 15813           374.0       845.0       330.0         1.5603
# 15814           150.0       356.0       114.0         2.5568
# 15815           485.0      1007.0       433.0         1.7000
# 15816           409.0       741.0       349.0         1.8672
# 15817           616.0      1387.0       530.0         2.3886
#
#        median_house_value ocean_proximity
# 0                352100.0        NEAR BAY
# 1                341300.0        NEAR BAY
# 2                342200.0        NEAR BAY
# 3                269700.0        NEAR BAY
# 4                299200.0        NEAR BAY
# ...                   ...             ...
# 15813             78100.0          INLAND
# 15814             77100.0          INLAND
# 15815             92300.0          INLAND
# 15816             84700.0          INLAND
# 15817             89400.0          INLAND
#
# [15818 rows x 11 columns]

# %%
list_cat = [j for j in df.columns if df.dtypes[j] == "object"]
list_cat
# Out:
# ['ocean_proximity']

# %%
df_dummies = pd.get_dummies(df, columns=list_cat, prefix="Column", dtype=float)
